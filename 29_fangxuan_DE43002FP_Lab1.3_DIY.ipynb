# %% [markdown]
# # DSP Lab 1.3
# ## Title:
# Data mapping and encoding in dataframe
#
# ## Objective:
# On completion of this lab, students should be able to:
# 1. Map the data according to specifications.
# 2. Perform data encoding.
#
# ## Tools, Equipment and Materials:
# 1. Personal Computer with Internet access
# 2. Jupyter Notebook / Pycharm / Spyder IDE

# %% [markdown]
# ***

# %% [markdown]
# # Data mapping using map()

# %% [markdown]
# <p><span style="color: #e67e23;"><span style="font-size: 16px;">We extract data from student_pc_internet.csv as an example.</span></span></p>

# %%
# import pandas package
import pandas as pd

# %%
# read the data from "student_pc_internet.csv" file and store it as student_info_df
student_info_df = pd.read_csv("./student_pc_internet.csv")

# remove the "id" column
student_info_df.pop("id")

# display student_info_df
display(student_info_df)
# Out:
#     first_name  last_name                      email       gender  laptop  \
# 0    Madeleine     Carman     mcarman0@hostgator.com       Female       1
# 1          Val      Vlies        vvlies1@godaddy.com       Female       1
# 2     Cindelyn  Seawright    cseawright2@example.com       Female       1
# 3        Nicko  Woodhouse        nwoodhouse3@163.com         Male       1
# 4         Nara     Zaczek      nzaczek4@google.co.uk       Female       1
# ..         ...        ...                        ...          ...     ...
# 195      Carri     Busher        cbusher5f@opera.com       Female       0
# 196   Melisent  Loutheane     mloutheane5g@unblog.fr       Female       0
# 197   Hendrick     Sherel  hsherel5h@liveinternet.ru         Male       1
# 198       Kean    Kepling       kkepling5i@tmall.com  Genderqueer       1
# 199     Powell     Soltan  psoltan5j@theatlantic.com   Non-binary       1
#
#      internet
# 0           0
# 1           0
# 2           0
# 3           1
# ...

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">From the student_info_df dataframe above, we observed that the laptop and internet columns contain values 1 and 0.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">The value 1 and 0 denotes "TRUE" and "FALSE" respectively.</span></p>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ### Map the laptop column

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">By using the mapping function we can add one more column to an existing dataframe.<br /></span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create a dictionary of the key values we wish to map and the replacement
Mapping_TF_dict = {1: 'TRUE', 0: 'FALSE'}

# using the 'laptop' to do the mapping and store it into a new column name 'laptop_TF'
student_info_df['laptop_TF'] = student_info_df['laptop'].map(Mapping_TF_dict)

# display the first 10 records
student_info_df.head(10)
# Out:
#     first_name  last_name                     email  gender  laptop  internet  \
# 0    Madeleine     Carman    mcarman0@hostgator.com  Female       1         0
# 1          Val      Vlies       vvlies1@godaddy.com  Female       1         0
# 2     Cindelyn  Seawright   cseawright2@example.com  Female       1         0
# 3        Nicko  Woodhouse       nwoodhouse3@163.com    Male       1         1
# 4         Nara     Zaczek     nzaczek4@google.co.uk  Female       1         0
# 5     Laurella  Pettiford  lpettiford5@addtoany.com  Female       0         1
# 6       Mariam    Ireland          mireland6@pen.io  Female       0         1
# 7  Christoforo    Scudder   cscudder7@tuttocitta.it    Male       1         0
# 8         Mada     Banger     mbanger8@symantec.com  Female       0         1
# 9        Scott    Sygrove      ssygrove9@flickr.com    Male       1         1
#
#   laptop_TF
# 0      TRUE
# 1      TRUE
# 2      TRUE
# 3      TRUE
# 4      TRUE
# 5     FALSE
# 6     FALSE
# ...

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="900" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Data mapping using apply() and lambda

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">We can also perform data mapping using apply() and lambda functions.</span></p>

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">A lambda function is a small anonymous function.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">A lambda function can take any number of arguments, but can only have one expression.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">Some example below:</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# lambda function example 1

# create a lambda fucntion to add 10
add_ten_func = lambda number1 : number1 + 10

# pass in the paramater add_ten_func() lambda function

add_ten_func(15)
# Out:
# 25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# lambda function example 2

# create a lambda fucntion to add 10
addition_func = lambda number1, number2, number3 : number1 + number2 + number3

# pass 3 paramaters addition_func() lambda function
addition_func(15,20,30)
# Out:
# 65

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# lambda function example 3

# create a lambda fucntion to add 10
check_even_func = lambda number1: True if (number1 % 2) == 0 else False

# pass 3 paramaters addition_func() lambda function
check_even_func(1623)
# Out:
# False

# %% [markdown]
# ### use the lambda function to do the mapping

# %% [markdown]
# <p><span style="color: #e67e23; font-size: 16px;">In the example below, we want to map the 'internet' column.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create a lambda function to map the true and false
mapping_func_TF = lambda x: 'TRUE' if x == 1 else 'FALSE'

# using the 'internet' to do the mapping and store it into a new column name 'internet_TF'
student_info_df['internet_TF'] = student_info_df['internet'].apply(mapping_func_TF)

# display the first 10 records
student_info_df.head
# Out:
# <bound method NDFrame.head of     first_name  last_name                      email       gender  laptop  \
# 0    Madeleine     Carman     mcarman0@hostgator.com       Female       1
# 1          Val      Vlies        vvlies1@godaddy.com       Female       1
# 2     Cindelyn  Seawright    cseawright2@example.com       Female       1
# 3        Nicko  Woodhouse        nwoodhouse3@163.com         Male       1
# 4         Nara     Zaczek      nzaczek4@google.co.uk       Female       1
# ..         ...        ...                        ...          ...     ...
# 195      Carri     Busher        cbusher5f@opera.com       Female       0
# 196   Melisent  Loutheane     mloutheane5g@unblog.fr       Female       0
# 197   Hendrick     Sherel  hsherel5h@liveinternet.ru         Male       1
# 198       Kean    Kepling       kkepling5i@tmall.com  Genderqueer       1
# 199     Powell     Soltan  psoltan5j@theatlantic.com   Non-binary       1
#
#      internet laptop_TF internet_TF
# ...

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="900" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Create new datafram by selecting columns from existing dataframe

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Once we done the mapping, we can create another dataframe by selecting the columns that we wanted from the student_info_df dataframe.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">To do this, we can specify the column name and pass in as a list, then use the copy() method.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">Example code below:</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# specify the column name and pass in as a list
# use the copy() method to create a new dataframe name as new_student_info_df
new_student_info_df = student_info_df[['first_name','last_name','email','gender',
                                     'laptop_TF','internet_TF']].copy()


# display the first 10 records
new_student_info_df.head(10)
# Out:
#     first_name  last_name                     email  gender laptop_TF  \
# 0    Madeleine     Carman    mcarman0@hostgator.com  Female      TRUE
# 1          Val      Vlies       vvlies1@godaddy.com  Female      TRUE
# 2     Cindelyn  Seawright   cseawright2@example.com  Female      TRUE
# 3        Nicko  Woodhouse       nwoodhouse3@163.com    Male      TRUE
# 4         Nara     Zaczek     nzaczek4@google.co.uk  Female      TRUE
# 5     Laurella  Pettiford  lpettiford5@addtoany.com  Female     FALSE
# 6       Mariam    Ireland          mireland6@pen.io  Female     FALSE
# 7  Christoforo    Scudder   cscudder7@tuttocitta.it    Male      TRUE
# 8         Mada     Banger     mbanger8@symantec.com  Female     FALSE
# 9        Scott    Sygrove      ssygrove9@flickr.com    Male      TRUE
#
#   internet_TF
# 0       FALSE
# 1       FALSE
# 2       FALSE
# 3        TRUE
# 4       FALSE
# 5        TRUE
# 6        TRUE
# 7       FALSE
# 8        TRUE
# 9        TRUE

# %% [markdown]
# ---

# %% [markdown]
# # Find the data distributions using value_counts()

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Pandas Index.value_counts() function returns object containing counts of unique values. </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">The resulting object will be in descending order so that the first element is the most frequently-occurring element. </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">The counting will exclude NA values by default.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# find out the total students with and with out laptop
new_student_info_df['laptop_TF'].value_counts()
# Out:
# laptop_TF
# FALSE    107
# TRUE      93
# Name: count, dtype: int64

# %%
# find out the total students with and with out internet at home
new_student_info_df['internet_TF'].value_counts()
# Out:
# internet_TF
# FALSE    109
# TRUE      91
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Categorise the data

# %% [markdown]
# <p><span style="color: #e67e23;"><span style="font-size: 16px;">We extract data from tuition_class.csv as an example.</span></span></p>

# %%
# read the data from "tuition_class.csv" file and store it as student_info_df
tuition_class_df = pd.read_csv("./tuition_class.csv")

# display tuition_class_df
display(tuition_class_df)
# Out:
#         Name  Age  Gender   PCI
# 0  Kean Seng   17    male   921
# 1       John   16    male   623
# 2      Ahmad   21    male  1010
# 3        Amy   18  female  1276
# 4     Kelvin   18    male  1975
# 5        Ali   16    male   589
# 6      Muthu   18    male  1006
# 7   Mei Ling   17  female   587
# 8     Joseph   20    male   628
# 9       Siti   21  female   948

# %% [markdown]
# ### Categorise data using cut() method

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">We will use cut when we need to segment and sort data values into bins (categorise the data). </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">This function is also useful for going from a numerical variable to a categorical variable. </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">For example, cut() could convert ages to groups of age ranges.&nbsp;</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">In the example below, we categorise the income category based on the PCI.</span></p>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import numpy package
import numpy as np

# bins are the range of numbers to categorise the data
bins = [0, 650, 1050, np.inf]

# labels are the specifies the labels for the returned bins
names = ['low income', 'middle income', 'high income']

# using the pd.cut() to categorise the income
tuition_class_df['Income'] = pd.cut(tuition_class_df['PCI'],bins, labels = names)

# display tuition_class_df
display(tuition_class_df)
# Out:
#         Name  Age  Gender   PCI         Income
# 0  Kean Seng   17    male   921  middle income
# 1       John   16    male   623     low income
# 2      Ahmad   21    male  1010  middle income
# 3        Amy   18  female  1276    high income
# 4     Kelvin   18    male  1975    high income
# 5        Ali   16    male   589     low income
# 6      Muthu   18    male  1006  middle income
# 7   Mei Ling   17  female   587     low income
# 8     Joseph   20    male   628     low income
# 9       Siti   21  female   948  middle income

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">bins are the range of numbers to categorise the data.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">labels are the specifies the labels for the returned bins.</span></p>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="800" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ### Categorise data using iterrows() & if-else

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">The DataFrame.iterrows() method iterates through Pandas DataFrame rows as (index, Series) pairs.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">The iterator returns a tuple of column names and data in the form of a series.</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">In the example code below, we have a dataframe that contains four observations: "Name," "Age," "Gender," and "PCI"</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# iterating over the datadrame rows Using df.iterrows()
for index, value in tuition_class_df.iterrows():
    print('index: ', index)
    print('value: ', value)
    print('-' * 50)


# code explaination:
# iterate through each row of the tuition_class_df dataframe
# print each observation as a tuple
# use iterrows() to get each observation as a tuple.
# Out:
# index:  0
# value:  Name          Kean Seng
# Age                  17
# Gender             male
# PCI                 921
# Income    middle income
# Name: 0, dtype: object
# --------------------------------------------------
# index:  1
# value:  Name            John
# Age               16
# Gender          male
# PCI              623
# Income    low income
# Name: 1, dtype: object
# --------------------------------------------------
# index:  2
# value:  Name              Ahmad
# Age                  21
# Gender             male
# PCI                1010
# Income    middle income
# Name: 2, dtype: object
# --------------------------------------------------
# index:  3
# value:  Name              Amy
# Age                18
# Gender         female
# PCI              1276
# Income    high income
# Name: 3, dtype: object
# --------------------------------------------------
# index:  4
# value:  Name           Kelvin
# Age                18
# Gender           male
# ...

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Now we already understand we can iterate the rows in a dataframe using interrows(). </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">Combine with the if-else decision making, we can categorise the data according to specified condition. </span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">In example below, we categorise the "Age" to "under 18" and "18 &amp; above" as shown below.</span></p>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600" align="left" style="border:1px solid green">
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create a empty list name as age_limit
age_limit = list()

# iterate each row in the tuition_class_df dataframe
# check the age and categorise them into "under 18" and "18 & above"
for index, value in tuition_class_df.iterrows():
    if value['Age'] < 18:
        age_limit.append("under 18")
    else:
        age_limit.append("18 & above")


# create a new column using the age_limit list
tuition_class_df["Age_limit"] = age_limit

# display tuition_class_df
display(tuition_class_df)
# Out:
#         Name  Age  Gender   PCI         Income   Age_limit
# 0  Kean Seng   17    male   921  middle income    under 18
# 1       John   16    male   623     low income    under 18
# 2      Ahmad   21    male  1010  middle income  18 & above
# 3        Amy   18  female  1276    high income  18 & above
# 4     Kelvin   18    male  1975    high income  18 & above
# 5        Ali   16    male   589     low income    under 18
# 6      Muthu   18    male  1006  middle income  18 & above
# 7   Mei Ling   17  female   587     low income    under 18
# 8     Joseph   20    male   628     low income  18 & above
# 9       Siti   21  female   948  middle income  18 & above

# %% [markdown]
# ### Find the data distribution using value_counts()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# find out the "Age_limit" distribution/propotion
tuition_class_df['Age_limit'].value_counts()

# %%
# find out the "Income" distribution/propotion
tuition_class_df['Income'].value_counts()
# Out:
# Income
# low income       4
# middle income    4
# high income      2
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # DIY Assignment:

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Following are the example code to read the "cars_info.csv" data and store it into car_df.</span></p>

# %%
# import pandas package
import pandas as pd

# %%
# read the data from "student_pc_internet.csv" file and store it as student_info_df
staff_records_df = pd.read_csv("./staff_records.csv")

# display student_info_df
display(staff_records_df)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">By using the staff_records_df dataframe, write the Python code on the following questions:</span></p>

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Q1: Display all columns' names.</span></p>

# %%
# Q1
# write your code in this code cell
# display all the column name
columns = pd.read_csv("./student_pc_internet.csv")
display(columns)
# Out:
#       id first_name  last_name                      email       gender  \
# 0      1  Madeleine     Carman     mcarman0@hostgator.com       Female
# 1      2        Val      Vlies        vvlies1@godaddy.com       Female
# 2      3   Cindelyn  Seawright    cseawright2@example.com       Female
# 3      4      Nicko  Woodhouse        nwoodhouse3@163.com         Male
# 4      5       Nara     Zaczek      nzaczek4@google.co.uk       Female
# ..   ...        ...        ...                        ...          ...
# 195  196      Carri     Busher        cbusher5f@opera.com       Female
# 196  197   Melisent  Loutheane     mloutheane5g@unblog.fr       Female
# 197  198   Hendrick     Sherel  hsherel5h@liveinternet.ru         Male
# 198  199       Kean    Kepling       kkepling5i@tmall.com  Genderqueer
# 199  200     Powell     Soltan  psoltan5j@theatlantic.com   Non-binary
#
#      laptop  internet
# 0         1         0
# 1         1         0
# 2         1         0
# ...

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Q2: Map the "Gender" column according to the following:</span></p>
# <p style="padding-left: 40px;"><span style="font-size: 12pt; color: #e67e23;">- "F": "Female"</span></p>
# <p style="padding-left: 40px;"><span style="font-size: 12pt; color: #e67e23;">- "M": Male</span></p>
# <p><span style="font-size: 12pt; color: #e67e23;">Store the mapped values into new column name it as "Gender_full"</span></p>

# %%
# Q2
# write your code in this code cell
Mapping_TF_dict = {'F': 'Female', 'M': 'Male'}
staff_records_df['Gender_full'] = student_info_df['Gender'].map(Mapping_TF_dict1)
staff_records_df.head(10)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
# 9  162402        Hon.      Diana              T  Peterson      F
#
#                          E Mail      Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com      Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com   Raymond Robinson       Judy Robinson
# ...

# %% [markdown]
# <p><span style="font-size: 12pt; color: #e67e23;">Q3: Find out the distribution of "Gender_full" column in the staff_records_df.</span></p>

# %%
# Q3
# write your code in this code cell
staff_records_df['Gender_full'].value_counts()
# Out:
# Gender_full
# Female    60
# Male      40
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="color: #e67e23; font-size: 16px;">After completion, rename this file as "INDEX_NAME_DE43002FP_Lab1.3_DIY.ipynb" and submit in myConnexion.</span></p>

# %%
29_fangxuan_DE43002FP_Lab1.3_DIY
