# %% [markdown]
# <h1 id="[Staff]-DSP-Trial-Test"><strong>DSP Trial Test </strong></h1>

# %% [markdown]
# ---

# %% [markdown]
# ## Instructions:
# ### Write the code by following the instruction in each part. You must complete all parts.

# %% [markdown]
# ## Parts:
# By using the 'Sales_100_records.csv' dataset, perform the following:
#
#     a. Read data from 'Sales_100_records.csv' and create data frame.
#     b. Create another data frame with only 'Region', 'Item Type', 'Total Revenue', 'Total Cost' and 'Total Profit' columns.
#     c. Show first 10 rows of filtered data frame.
#     d. Show last 10 rows of filtered data frame.
#     e. Group the filtered data frame by 'Region'.
#     f. Find the sum of 'Total Profit' in each region.
#     g. Display the top 5 region according to 'Total Profit'.
#     f. Repeat the necessary coding to display top 5 'Item Type' according to 'Total Revenue'.

# %% [markdown]
# ### Load Python libraries or packages.

# %%
# load all necessary libraries and packages
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extract data from 'Sales_100_records.csv'.

# %%
# read 'Sales_100_records.csv' and creating dataframe
# store the dataframe as 'sales_df'
sales_df = pd.read_csv("./Sales_100_records.csv")
    
# display the dataframe 
sales_df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# display the descritive statistic of dataframe
descritive = sales_df.describe()
descritive

# %%
# display column name of dataframe
sales_df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# ### Extract column 'Region', 'Item Type', 'Total Revenue', 'Total Cost' and 'Total Profit'.

# %%
# Extract column 'Region', 'Item Type', 'Total Revenue', 'Total Cost' and 'Total Profit'
# store as sales_region_df
sales_region_df = sales_df[['Region', 'Item Type', 'Total Revenue', 'Total Cost', 'Total Profit']]



# show the results
sales_region_df
# Out:
#                                Region        Item Type  Total Revenue  \
# 0               Australia and Oceania        Baby Food     2533654.00
# 1   Central America and the Caribbean           Cereal      576782.80
# 2                              Europe  Office Supplies     1158502.59
# 3                  Sub-Saharan Africa           Fruits       75591.66
# 4                  Sub-Saharan Africa  Office Supplies     3296425.02
# ..                                ...              ...            ...
# 95                 Sub-Saharan Africa          Clothes       97040.64
# 96                               Asia           Fruits       58471.11
# 97                 Sub-Saharan Africa       Vegetables      228779.10
# 98                      North America    Personal Care      471336.91
# 99                 Sub-Saharan Africa        Household     3586605.09
#
#     Total Cost  Total Profit
# 0   1582243.50     951410.50
# 1    328376.44     248406.36
# 2    933903.84     224598.75
# ...

# %% [markdown]
# ### Display dimension, first 10 rows and last 20 rows

# %%
# display the dimension of sales_region_df
sales_region_df.shape
# Out:
# (100, 5)

# %%
# show the first 10 rows of sales_region_df
sales_region_df.head(10)
# Out:
#                               Region        Item Type  Total Revenue  \
# 0              Australia and Oceania        Baby Food     2533654.00
# 1  Central America and the Caribbean           Cereal      576782.80
# 2                             Europe  Office Supplies     1158502.59
# 3                 Sub-Saharan Africa           Fruits       75591.66
# 4                 Sub-Saharan Africa  Office Supplies     3296425.02
# 5              Australia and Oceania        Baby Food      759202.72
# 6                 Sub-Saharan Africa        Household     2798046.49
# 7                 Sub-Saharan Africa       Vegetables     1245112.92
# 8                 Sub-Saharan Africa    Personal Care      496101.10
# 9                 Sub-Saharan Africa           Cereal     1356180.10
#
#    Total Cost  Total Profit
# 0  1582243.50     951410.50
# 1   328376.44     248406.36
# 2   933903.84     224598.75
# 3    56065.84      19525.82
# 4  2657347.52     639077.50
# 5   474115.08     285087.64
# ...

# %%
# show the last 20 rows of sales_region_df
sales_region_df.tail(20)
# Out:
#                                Region        Item Type  Total Revenue  \
# 80                             Europe        Household     3015902.51
# 81       Middle East and North Africa          Clothes      861563.52
# 82       Middle East and North Africa        Cosmetics     2836990.80
# 83                 Sub-Saharan Africa           Snacks      623289.30
# 84                 Sub-Saharan Africa       Vegetables      994765.42
# 85                      North America    Personal Care      524870.06
# 86                 Sub-Saharan Africa        Beverages      418936.05
# 87                 Sub-Saharan Africa        Baby Food     1419101.52
# 88       Middle East and North Africa           Fruits        4870.26
# 89                             Europe        Beverages      221117.00
# 90                 Sub-Saharan Africa  Office Supplies      617347.08
# 91              Australia and Oceania        Beverages      445508.05
# ...

# %% [markdown]
# ### Group sales_region_df by 'Region'.

# %%
# group the dataframe by 'Region'
# store the dataframe as 'grouped_region_df'
group_sales_region_df = sales_region_df.groupby('Region')

# display the group dataframe
#display(list(grouped_region_df))
group_sales_region_df.apply(display)
# Out:
#    Region        Item Type  Total Revenue  Total Cost  Total Profit
# 10   Asia       Vegetables       19103.44    11275.32       7828.12
# 12   Asia          Clothes      902980.64   296145.92     606834.72
# 14   Asia    Personal Care      400558.73   277739.67     122819.06
# 16   Asia        Cosmetics     3039414.40  1830670.16    1208744.24
# 18   Asia        Household     2559474.10  1924728.20     634745.90
# 33   Asia        Household     5513227.50  4145955.00    1367272.50
# 38   Asia  Office Supplies     4368316.68  3521431.68     846885.00
# 44   Asia          Clothes      648030.40   212531.20     435499.20
# 70   Asia  Office Supplies     3262562.10  2630049.60     632512.50
# 77   Asia       Vegetables      574951.92   339350.76     235601.16
# 96   Asia           Fruits       58471.11    43367.64      15103.47
#                    Region        Item Type  Total Revenue  Total Cost  \
# 0   Australia and Oceania        Baby Food     2533654.00  1582243.50
# ...

# %% [markdown]
# ### Find the sum of total profit for each region.

# %%
# sum of the total profit by region
# store dataframe as 'sum_profit_df'
sumsales100 = group_sales_region_df['Total Profit'].sum()

# display the dataframe
sumsales100
# Out:
# Region
# Asia                                  6113845.87
# Australia and Oceania                 4722160.03
# Central America and the Caribbean     2846907.85
# Europe                               11082938.63
# Middle East and North Africa          5761191.86
# North America                         1457942.76
# Sub-Saharan Africa                   12183211.40
# Name: Total Profit, dtype: float64

# %% [markdown]
# ### Sort the 'Total Profit' in decending order, and then display top 5 region.
# ### This result will be "Find top 5 'Total Profit' by 'Region"

# %%
# find top 5 total profit by regions
summed = group_sales_region_df.sum()
top5profit = summed.sort_values(by='Total Profit', ascending=False).head(5)
top5profit.head(5)
# Out:
#                                                                       Item Type  \
# Region
# Sub-Saharan Africa            FruitsOffice SuppliesHouseholdVegetablesPerson...
# Europe                        Office SuppliesClothesBaby FoodBaby FoodPerson...
# Asia                          VegetablesClothesPersonal CareCosmeticsHouseho...
# Middle East and North Africa  FruitsCosmeticsCerealClothesFruitsCosmeticsClo...
# Australia and Oceania         Baby FoodBaby FoodMeatFruitsFruitsOffice Suppl...
#
#                               Total Revenue   Total Cost  Total Profit
# Region
# Sub-Saharan Africa              39672031.43  27488820.03   12183211.40
# Europe                          33368932.11  22285993.48   11082938.63
# Asia                            21347091.02  15233245.15    6113845.87
# Middle East and North Africa    14052706.58   8291514.72    5761191.86
# Australia and Oceania           14094265.13   9372105.10    4722160.03

# %% [markdown]
# ---

# %% [markdown]
# ### Repeat necessary steps
# ### Find top 5 'Total Revenue' by 'Item Type'

# %%
# write your code here
grouped_item_df = sales_region_df.groupby('Item Type')
grouped_item_df.apply(display)
sum_revenue_df.nlargest(5, 'Total Revenue')
# Out:
#                    Region  Item Type  Total Revenue  Total Cost  Total Profit
# 0   Australia and Oceania  Baby Food     2533654.00  1582243.50     951410.50
# 5   Australia and Oceania  Baby Food      759202.72   474115.08     285087.64
# 20                 Europe  Baby Food     1901836.00  1187679.00     714157.00
# 21                 Europe  Baby Food      324971.44   202941.66     122029.78
# 61                 Europe  Baby Food     1212580.00   757245.00     455335.00
# 78                 Europe  Baby Food     2198981.92  1373243.88     825738.04
# 87     Sub-Saharan Africa  Baby Food     1419101.52   886215.78     532885.74
#                                Region  Item Type  Total Revenue  Total Cost  \
# 17                 Sub-Saharan Africa  Beverages      257653.50   172619.70
# 28                             Europe  Beverages      243133.80   162891.96
# 72                 Sub-Saharan Africa  Beverages      272410.45   182506.39
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Submission:
# #### 1. Save this file as "Index_Name_DSP_TrialTest.ipynb"
# #### 2. Submit this file to your Lecturer

# %%
29_fangxuan_DSP_TrialTest
