# %% [markdown]
# <h1 id="Higher-NITEC-in-Data-Engineering" style="text-align: center;">Higher NITEC in Data Engineering</h1>
# <h1 id="DE53002FP---Data-Preparation-for-Machine-Learning" style="text-align: center;">DE53002FP - Data Preparation for Machine Learning</h1>
# <p><br /><br /></p>
# <h2 id="Practical-Assignment" style="text-align: center;">Practical Assignment</h2>
# <p style="text-align: center;">&nbsp;</p>
# <h3 id="&nbsp;" style="text-align: center;">Data Preparation for Improving Production Efficiency in Manufacturing</h3>

# %% [markdown]
# ---

# %% [markdown]
# ## Scenario Introduction:
# Welcome to your role as an Assistant Data Engineer at EfficientManufacture Inc., a leading manufacturing company dedicated to optimizing its production processes. The company has amassed extensive data from its manufacturing operations, including machine performance metrics, production volumes, quality control records, and maintenance logs. Your task is to prepare this data for further analysis to identify opportunities for enhancing production efficiency.

# %% [markdown]
# ---

# %% [markdown]
# ## Problem Statement:
# **EfficientManufacture Inc.** is dedicated to **enhancing its production efficiency by leveraging comprehensive operational data to identify the most impactful factors influencing performance**. As an **Assistant Data Engineer**, your primary responsibility is to prepare and refine the provided dataset to ensure it is clean, accurate, and suitable for in-depth analysis. To effectively improve production efficiency, it is **crucial to discern which aspects of the manufacturing process are most significant**. Consider how different elements such as production volumes, machine reliability, quality outcomes, maintenance investments, and workforce expertise might influence overall performance.

# %% [markdown]
# ---

# %% [markdown]
# ## Objective:
#
# Your specific objectives are to:
#
# Import the manufacturing dataset into Python using Jupyter Notebook.
# Interpret the problem statement to identify and select relevant features that influence production efficiency.
# Plot appropriate charts to detect outliers in the data.
# Replace missing data using suitable methods to ensure a complete dataset.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset Description:
# The synthetic dataset provided for this practical assignment simulates operational data from **EfficientManufacture Inc.**, a manufacturing company aiming to improve its production efficiency. The dataset comprises 250 records and includes a mix of relevant and non-relevant variables to reflect a realistic manufacturing environment. Below is a detailed description of each variable in the dataset.

# %% [markdown]
# <figure class="table" style="width: 81.64%;">
# <h3><strong><span style="font-size: 12.0pt; line-height: 115%; font-family: 'Aptos',sans-serif; mso-ascii-theme-font: minor-latin; mso-fareast-font-family: DengXian; mso-fareast-theme-font: minor-fareast; mso-hansi-theme-font: minor-latin; mso-bidi-font-family: 'Times New Roman'; mso-bidi-theme-font: minor-bidi; mso-ansi-language: EN-SG; mso-fareast-language: ZH-CN; mso-bidi-language: AR-SA;">Variables Overview:</span></strong></h3>
# <p>&nbsp;</p>
# <table class="ck-table-resized"><colgroup><col style="width: 22.45%;" /><col style="width: 77.55%;" /></colgroup>
# <tbody>
# <tr>
# <td class="xl63" style="border-style: none; height: 15pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; text-align: center; vertical-align: middle; width: 118pt;" width="157" height="20">
# <p style="text-align: left;"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Variable Name</strong></span></p>
# </td>
# <td class="xl63" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; text-align: left; vertical-align: middle; width: 185pt;" width="246">
# <p style="text-align: justify;"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Description</strong></span></p>
# </td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Machine_ID</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Unique identifier for each machine used in the manufacturing process.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Production_Volume</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Number of units produced by a machine within a specific timeframe.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 45pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="60"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Downtime_Hours</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Total hours a machine was non-operational due to maintenance, breakdowns, or other issues.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Quality_Defects</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Number of defective units produced, indicating the quality of output.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Maintenance_Cost</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Cost incurred for maintaining and servicing each machine.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Operator_ID</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Unique identifier for each machine operator or technician.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Operator_Experience</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Years of experience each operator has in operating machinery.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 45pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="60"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Shift</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Type of work shift assigned to operators.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Employee_Satisfaction</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Satisfaction score of employees on a scale of 1 to 5.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 45pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="60"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Raw_Material_Supplier</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Name of the supplier providing raw materials.</span></td>
# </tr>
# <tr style="text-align: left;">
# <td class="xl65" style="border-style: none; height: 45pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="60"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Employee_Shift_Timing</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt; text-align: left;" width="246"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Specific timing of an employee's shift.</span></td>
# </tr>
# <tr>
# <td class="xl65" style="border-style: none; height: 30pt; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 118pt; text-align: left;" width="157" height="40"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;"><strong>Lunch_Break_Duration</strong></span></td>
# <td class="xl64" style="border-style: none; padding-left: 1px; padding-right: 1px; padding-top: 1px; vertical-align: middle; width: 185pt;" width="246">
# <p style="text-align: left;"><span style="font-family: 'Aptos Narrow', sans-serif; font-size: 11pt;">Duration of the employee's lunch break in minutes.</span></p>
# </td>
# </tr>
# </tbody>
# </table>
# </figure>

# %% [markdown]
# ---

# %% [markdown]
# <h2 id="Tasks/Deliverables:" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>Tasks/Deliverables:</strong></h2>
# <p>You are required to complete the following tasks:</p>
# <h3 id="1.-Import-Data-from-New-Data-Sources" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>1. Import Data from New Data Sources</strong></h3>
# <ul>
# <li>Obtain the provided manufacturing dataset.</li>
# <li>Import the dataset into your Python environment using Jupyter Notebook.</li>
# </ul>
# <h3 id="2.-Interpret-the-Problem-Statement-Correctly" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>2. Interpret the Problem Statement Correctly</strong></h3>
# <ul>
# <li>Analyse the problem statement to understand the key objectives.</li>
# <li>Identify and select the most relevant features from the dataset that impact production efficiency.</li>
# </ul>
# <h3 id="3.-Plot-Charts-for-Outlier-Detection" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>3. Plot Charts for Outlier Detection</strong></h3>
# <ul>
# <li>Explore the dataset to understand the statistics/distribution of each feature.</li>
# <li>Choose and create appropriate visualisations to identify outliers in the selected features.</li>
# </ul>
# <h3 id="4.-Replace-Missing-Data" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>4. Replace Missing Data</strong></h3>
# <ul>
# <li>Detect missing values in the dataset.</li>
# <li>Apply suitable methods to replace missing data, ensuring the integrity of the dataset is maintained.</li>
# </ul>

# %% [markdown]
# ---

# %% [markdown]
# <h2><strong>Instructions</strong></h2>
# <p>Follow the steps below to complete the assignment:</p>

# %% [markdown]
# <h3 id="1.-Importing-the-Dataset"><strong>1. Importing the Dataset</strong></h3>
# <ul>
# <li>
# <p><strong>Dataset Source: </strong>https://raw.githubusercontent.com/khiew-tzong-yong/hf3de_m7/refs/heads/main/manufacturing_data.csv&nbsp;&nbsp;</p>
# </li>
# <li><strong>Load the Dataset: </strong>Import the dataset into your Jupyter Notebook using pandas.</li>
# </ul>

# %%
url = "https://raw.githubusercontent.com/khiew-tzong-yong/hf3de_m7/refs/heads/main/manufacturing_data.csv"

# Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h3 id="2.-Interpreting-the-Problem-Statement-and-Selecting-Features"><strong>2. Interpreting the Problem Statement and Selecting Features</strong></h3>
# <ul>
# <li>
# <p><strong>Understand the Objective:</strong></p>
# <ul>
# <li>The goal is to improve production efficiency. Determine which features in the dataset are likely to influence this objective.</li>
# </ul>
# </li>
# <li>
# <p><strong>Select Relevant Features:</strong></p>
# <ul>
# <li>Based on your understanding, identify and select the most relevant features from the dataset that impact production efficiency.</li>
# </ul>
# </li>
# <li><strong>Create dataframe:</strong>
# <ul>
# <li>Create a dataframe using the selected relevant features.</li>
# </ul>
# </li>
# </ul>

# %%
# Write your code here

df = pd.read_csv(url)
df.head()

manufacturing_data = [
    'Production_Volume',
    'Downtime_Hours',
    'Quality_Defects',
    'Maintenance_Cost',
    'Operator_Experience',
    'Shift',
    'Employee_Satisfaction',
    'Lunch_Break_Duration'
]

df_problemstatement = df[manufacturing_data]
df_problemstatement.head()
# Out:
#    Production_Volume  Downtime_Hours  Quality_Defects  Maintenance_Cost  \
# 0              495.0             3.0              4.0            3414.0
# 1              515.0             4.0              5.0            2709.0
# 2              594.0             2.6              6.0            3424.0
# 3              580.0             8.2              4.0            2712.0
# 4              513.0             3.5              4.0            3519.0
#
#    Operator_Experience    Shift  Employee_Satisfaction  Lunch_Break_Duration
# 0                    2    Night                      2                    60
# 1                   10  Evening                      1                    45
# 2                    3    Night                      3                    30
# 3                    6  Evening                      3                    60
# 4                    8  Morning                      2                    45

# %% [markdown]
# <h3><strong>4. Plotting Charts for Outlier Detection</strong></h3>
# <ul>
# <li>
# <p><strong>Explore Data statistics/Distribution:</strong></p>
# <ul>
# <li>Use descriptive statistics to understand the data statistics/distribution of each selected feature.</li>
# </ul>
# </li>
# </ul>

# %%
# Write your code here

for column in df_problemstatement.columns:
    if df_problemstatement[column].dtype != 'object': 
        plt.figure(figsize=(8, 6))
        sns.boxplot(x=df_problemstatement[column])
        plt.title(f'Box Plot of {column}')
        plt.xlabel(column)
        plt.show()

# %% [markdown]
# <ul>
# <li>
# <p><strong>Visualise Outliers:</strong></p>
# <ul>
# <li>Create appropriate visualisations to identify outliers in the selected features.</li>
# </ul>
# </li>
# </ul>

# %%
# Write your code here
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='Downtime_Hours',
    y='Production_Volume',
    data=df_problemstatement,
    hue='Shift',
    palette='Set2'
)
plt.title('Downtime vs Production Volume')
plt.xlabel('Downtime (Hours)')
plt.ylabel('Production Volume')
plt.grid(True)
plt.show()

# %% [markdown]
# <h3 id="5.-Replacing-Missing-Data" style="color: #000000; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;"><strong>5. Replacing Missing Data</strong></h3>
# <ul>
# <li>
# <p><strong>Identify Missing Values:</strong></p>
# <ul>
# <li>
# <p>Detect any missing values in the selected features of the dataset.</p>
# </li>
# </ul>
# </li>
# </ul>

# %%
# Write your code here
missing_values = df_problemstatement.isnull().sum()
print("Missing values per column:\n")
missing_values
# Out:
# Missing values per column:
# Production_Volume        32
# Downtime_Hours            6
# Quality_Defects          16
# Maintenance_Cost         12
# Operator_Experience       0
# Shift                     0
# Employee_Satisfaction     0
# Lunch_Break_Duration      0
# dtype: int64

# %% [markdown]
# <ul>
# <li>
# <p><strong>Handle Missing Data:</strong></p>
# <ul>
# <li>Choose and apply suitable methods to replace the missing data, ensuring the dataset remains complete and reliable.</li>
# </ul>
# </li>
# </ul>

# %%
# Write your code here

missing_values = df_problemstatement.fillna(df_problemstatement.mean)
missing_values.isnull().sum()
# Out:
# Production_Volume        0
# Downtime_Hours           0
# Quality_Defects          0
# Maintenance_Cost         0
# Operator_Experience      0
# Shift                    0
# Employee_Satisfaction    0
# Lunch_Break_Duration     0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Submission
# - Rename this file as "YourName_DE53002FP_PA_Coding.ipynb"
# - SUbmit the file to myConnexion.
