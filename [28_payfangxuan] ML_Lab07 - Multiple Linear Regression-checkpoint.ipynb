# %% [markdown]
# <h2><span style="color: #236fa1;">ML_Lab 07</span></h2>
# <h3 id="Title:-Multiple-Linear-Regression" style="font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; color: #000000;"><span style="color: #236fa1;">Title: Multiple Linear Regression</span></h3>
# <h3 id="Objective:" style="font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; color: #000000;"><span style="color: #236fa1;">Objective:</span></h3>
# <p><span style="color: #236fa1; font-size: 12pt;">After completion of this lab, students should be able to:</span></p>
# <ol>
# <li><span style="color: #236fa1; font-size: 12pt;">predict data modelling using multiple linear regression.</span></li>
# <li><span style="color: #236fa1; font-size: 12pt;">visualise the relationship between variables.</span></li>
# <li><span style="color: #236fa1; font-size: 12pt;">plot predicted linear line with jointplot.</span></li>
# <li><span style="color: #236fa1; font-size: 12pt;">perform data prediction.</span></li>
# </ol>
# <h3 id="Tools,-Equipment-and-Materials:" style="font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; color: #000000;"><span style="color: #236fa1;">Tools, Equipment and Materials:</span></h3>
# <ol>
# <li>
# <p><span style="color: #236fa1; font-size: 12pt;">Personal Computer with Internet access</span></p>
# </li>
# <li>
# <p><span style="color: #236fa1; font-size: 12pt;">Jupyter Notebook</span></p>
# </li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# <h1><span style="color: #236fa1;">Instruction:</span></h1>

# %% [markdown]
# <p><span style="text-decoration: underline;"><strong><span style="color: #236fa1; font-size: 12pt; text-decoration: underline;">Import libraries</span></strong></span></p>
# <p><span style="color: #236fa1; font-size: 12pt;">Import necessary Python libraries.</span></p>

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# <h1 id="Multiple-Linear-Regression"><span style="color: #236fa1;">Multiple Linear Regression</span></h1>

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">Multiple linear regression is like linear regression, but with more than one independent value, meaning that we try to predict a value based on two or more variables.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Multiple linear regression indicates that we will have many features(variables). Such as f1, f2, f3, f4, and our output feature f5.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Take a look at the data set below, it contains information about cars.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import "cars.csv" file from the same folder directory
# dataset source: https://www.w3schools.com/python/cars.csv
cars_df = pd.read_csv("./cars.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# print first 5 rows of records of cars_df
cars_df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# print last 5 rows of records of cars_df
cars_df.tail()
# Out:
#          Car   Model  Volume  Weight  CO2
# 31     Volvo    XC70    2000    1746  117
# 32      Ford   B-Max    1600    1235  104
# 33       BMW     216    1600    1390  108
# 34      Opel  Zafira    1600    1405  109
# 35  Mercedes     SLK    2500    1395  120

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# display the rows and columns of the dataframe
cars_df.shape
# Out:
# (36, 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# display all car brand
cars_df["Car"].unique()
# Out:
# array(['Toyoty', 'Mitsubishi', 'Skoda', 'Fiat', 'Mini', 'VW', 'Mercedes',
#        'Ford', 'Audi', 'Hyundai', 'Suzuki', 'Honda', 'Hundai', 'Opel',
#        'BMW', 'Mazda', 'Volvo'], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# display all car model
cars_d

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="text-decoration: underline;"><strong><span style="font-size: 12pt; color: #236fa1; text-decoration: underline;">Heatmap on the correlation coefficient</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">We can create dataframe using the variables and visualise the correlation of variables using Seaborn heatmap.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# change the plotting style

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="text-decoration: underline; color: #236fa1;"><strong><span style="font-size: 12pt;">Pairplot - the relationship of all variables</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">We can use pairplot visualizes the relationship of all variables in the dataframe.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# visualizes the relationship of all variables

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="text-decoration: underline; color: #236fa1;"><strong><span style="font-size: 12pt;">Jointplot - the relationship of two variables and predict best-fit line</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">We can also use jointplot to visualise the relationship between "Volume" and "CO2".</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# visualise the relationship between "Volume" and "CO2" with predicted line

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">Similarly, we can also use jointplot to visualise the relationship between "Weight" and "CO2".</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# visualise the relationship between "Weight" and "CO2" with predicted line

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">From the heatmap, pairplot and jointplot, we can see the positive correlation.</span></p>

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="text-decoration: underline; color: #236fa1;"><strong><span style="font-size: 12pt;">Predict best-fit line</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">We can predict the CO2 emission of a car based on the size of the engine.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">With multiple linear regression, we can use more independent variables, such as the weight of the car, to make the prediction more accurate.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Here, we make a list of independent variables X containing "Weight" and "Volume" columns.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">The dependent value is "CO2" column.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# list of independent variables X containing "Weight" and "Volume" columns


# dependent value is "CO2" column

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">Next, we will continue the usual linear regression modelling.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#importing the LinearRegression class from sklearn.linear_model


# create a new instance of the LinearRegression class and name it as lm


# use the fit() method to train the linear regression model using X and y

# %% [markdown]
# <p><span style="text-decoration: underline;"><strong><span style="font-size: 12pt; color: #236fa1; text-decoration: underline;">Best-fit line score value</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Use sklearn's metrics to calculate the R-squared value.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# find out the r-squared value of best-fit line

# %% [markdown]
# <p><span style="text-decoration: underline;"><strong><span style="color: #236fa1; font-size: 12pt; text-decoration: underline;">Two important attributes of best-fit line</span></strong></span></p>
# <p><span style="color: #236fa1; font-size: 12pt;">The slope coefficient and intercept of the predicted data can be display using coef_ and intercept_.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# display the slope coefficient and intercept of the predicted best-fit line

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="text-decoration: underline; color: #236fa1;"><strong><span style="font-size: 12pt;">Data prediction using the data model</span></strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Now, we are ready to predict CO2 values based on a car's weight and volume.</span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">For example, a car with weight of 2000kg and volume of 1200cm^3.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# predict the CO2 emission of a car where the weight is 2000kg, and the volume is 1200cm^3:

# %% [markdown]
# <p><span style="text-decoration: underline; font-size: 12pt; color: #236fa1;"><strong>Conclusion on data prediction</strong></span></p>
# <p><span style="font-size: 12pt; color: #236fa1;">Based on the prediction, we have a car with 1.2 liter engine, and a weight of 2000 kg, which will release approximately 104.2 grams of CO2 for every kilometer it drives.</span></p>

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">Next, we can create a dataframe of the coefficient.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create dataframe of coefficient on best-fit line

# %% [markdown]
# <p><span style="font-size: 12pt; color: #236fa1;">Interpreting the coefficients above:</span></p>
# <ul>
# <li><span style="font-size: 12pt; color: #236fa1;">Holding all other features fixed, a 1 unit increase in Weight is associated with an increase of 0.007551 grams CO2 released.</span></li>
# <li><span style="font-size: 12pt; color: #236fa1;">Holding all other features fixed, a 1 unit increase in Volume is associated with an increase of 0.007805 grams CO2 released.</span></li>
# </ul>

# %% [markdown]
# ---

# %% [markdown]
# <p><span style="color: #236fa1; font-size: 16px;">After completion, rename this file as "INDEX_NAME_DE53004FP_ML_Lab07.ipynb" and submit in myConnexion.</span></p>

# %% [markdown]
# ![image.png](attachment:image.png)
# Source: https://matplotlib.org/2.0.2/_images/named_colors.png

# %% [markdown]
# ![image.png](attachment:image.png)
# Source: https://www.cdslab.org/python/notes/visualization/2d/symbols.png
