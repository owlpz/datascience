# %% [markdown]
# <h1 id="Higher-NITEC-in-Data-Engineering" style="text-align: center;">Higher NITEC in Data Engineering</h1>
# <h1 id="DE4002FP---Data-Science-Programming" style="text-align: center;">DE4002FP - Data Science Programming</h1>
# <p><br /><br /></p>
# <h2 id="Practical-Assignment-2" style="text-align: center;">Project</h2>

# %% [markdown]
# ---

# %% [markdown]
# ### Title:- Develop program codes for visual analysis using data science libraries

# %% [markdown]
# ### Tools, equipment and material:-
#     1. Personal Computer with Internet access
#     2. Jupyter Notebook / Pycharm /Spyder IDE
#     3. Source file (StudentsPerformance.csv), available at:-
#         https://github.com/AlameluRamanathan/M2-DSP

# %% [markdown]
# ---

# %% [markdown]
# ### StudentsPerformance.csv dataset information:-
# The dataset consists of the marks secured by the students in various subjects. There are 1000 occurrences and 8 columns.
#
# Following are the columns name:
#
#     1. gender
#     2. race / ethnicity
#     3. parental level of education
#     4. lunch
#     5. test preparation course
#     6. math score
#     7. reading score
#     8. writing score
#
# Explore the dataset to understand the influence of the parent’s background, test preparation etc. on student’s performance. The dataset comprises of 1,000 rows and 8 columns, with which we continue to determine what all the features which plays a vital role in affecting the student's performance, and we also try to solve some of the myths for example : students who perform good in math is bad at writing.

# %% [markdown]
# ### Instructions:-
#
# #### You are programmer tasked to write codes to perform visual analysis of the given dataset “StudentsPerformance.csv”. The following are the project requirements:

# %% [markdown]
# ### 1. Import all required Python libraries.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Apply appropriate programming logics.

# %% [markdown]
# ### 2a. Data extraction and basic data inspection.

# %%
# write code to extract data from 'StudentsPerformance.csv' (note: dataframe will be created when read csv file)
studentperformance_df=pd.read_csv(".//StudentsPerformance.csv")
studentperformance_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# write code to display first 10 rows of data extracted
studentperformance_df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92
# 7                    none          40             43             39
# 8               completed          64             64             67
# 9                    none          38             60             50

# %%
# write code to display last 10 rows of data extracted
studentperformance_df.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# write code to find out the shape of the data (rows and columns)
studentperformance_df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### 2b. Detecting missing values, null values, duplicate and rename columns.

# %%
# write code to display dataframe information
studentperformance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# write code to check out for total number of null values on each columns
studentperformance_df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# write code to check for duplicate records in all rows
studentperformance_df.duplicated().sum()
# Out:
# 0

# %%
# write code to display original dataframe columns
studentperformance_df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# analyse columns name display above, check if columns name contain symbol or space.
# if it contain symbol or space, write code to replace it with '_'. 
# As a result, column name should be continuous string without space
for col in studentperformance_df.columns:
    if any(char in col for char in [' ', '-', '/']):
        replace_df = col.replace(' ', '_').replace('-', '_').replace('/', '_')
        studentperformance_df.rename(columns={col: replace_df}, inplace=True)

# %%
# write code to display modified dataframe columns
# double check if all columns name does not contain symbol or space and it should be continuous string without space
studentperformance_df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# ### 2c. Statistical measures to describe and analyses data.

# %%
# write code describe the dataframe summary statistics (example: count, mean, std, etc....)
# note: only focus on 'math_score', 'reading_score' and 'writing_score'
summarystudentperformance_df = studentperformance_df[['math_score', 'reading_score', 'writing_score']].describe()
summarystudentperformance_df
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# write code to group dataframe by 'gender'
grouped_gender_df=data_df.groupby('gender')
grouped_gender_df.apply(display)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [518 rows x 8 columns]
#     gender race/ethnicity parental_level_of_education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 3                      none          47             57             44
# 4                      none          76             78             75
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 10                     none          58             54             52
# ..                      ...         ...            ...            ...
# 985                    none          57             51             54
# 987               completed          81             75             76
# 990               completed          86             81             75
# 994                    none          63             63             62
# 996                    none          62             55             55
#
# [482 rows x 8 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# write code to count the 'gender'
studentgender_count_df = studentperformance_df['gender'].value_counts()
studentgender_count_df
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# write code to group dataframe by 'race_ethnicity'
grouped_race_df=studentperformance_df.groupby('race_ethnicity')
grouped_race_df.apply(display)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# 25     male        group A             master's degree  free/reduced
# 46   female        group A          associate's degree      standard
# ..      ...            ...                         ...           ...
# 974  female        group A                some college      standard
# 983  female        group A                some college      standard
# 985    male        group A                 high school      standard
# 988  female        group A            some high school  free/reduced
# 994    male        group A                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 3                      none          47             57             44
# 13                completed          78             72             70
# 14                     none          50             53             58
# 25                     none          73             74             72
# 46                completed          55             65             62
# ..                      ...         ...            ...            ...
# 974                    none          54             63             67
# 983               completed          78             87             91
# 985                    none          57             51             54
# 988                    none          44             45             45
# 994                    none          63             63             62
#
# [89 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# ..      ...            ...                         ...           ...
# 969  female        group B           bachelor's degree      standard
# 976    male        group B                some college  free/reduced
# 980  female        group B                 high school  free/reduced
# 982    male        group B            some high school      standard
# 991  female        group B            some high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# 7                      none          40             43             39
# ..                      ...         ...            ...            ...
# 969                    none          75             84             80
# 976               completed          60             62             60
# 980                    none           8             24             23
# 982               completed          79             85             86
# 991               completed          65             82             78
#
# [190 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 10     male        group C          associate's degree      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 984  female        group C            some high school      standard
# 986  female        group C          associate's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 1                 completed          69             90             88
# 4                      none          76             78             75
# 10                     none          58             54             52
# 15                     none          69             75             78
# 16                     none          88             89             86
# ..                      ...         ...            ...            ...
# 979                    none          91             95             94
# 984                    none          74             75             82
# 986                    none          40             59             51
# 996                    none          62             55             55
# 997               completed          59             71             65
#
# [319 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 8      male        group D                 high school  free/reduced
# 11     male        group D          associate's degree      standard
# 20     male        group D                 high school      standard
# 22     male        group D                some college      standard
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 8                 completed          64             64             67
# 11                     none          40             52             43
# 20                     none          66             69             63
# 22                     none          44             54             53
# 24                completed          74             71             80
# ..                      ...         ...            ...            ...
# 989               completed          67             86             83
# 992                    none          55             76             76
# 993                    none          62             72             74
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [262 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 32   female        group E             master's degree  free/reduced
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 44   female        group E          associate's degree  free/reduced
# 50     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 962  female        group E          associate's degree      standard
# 968  female        group E          associate's degree      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 32                     none          56             72             65
# 34                     none          97             87             82
# 35                completed          81             81             79
# 44                     none          50             56             54
# 50                     none          53             55             48
# ..                      ...         ...            ...            ...
# 962                    none         100            100            100
# 968                    none          68             76             67
# 987               completed          81             75             76
# 990               completed          86             81             75
# 995               completed          88             99             95
#
# [140 rows x 8 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# write code to count the different group of 'race_ethnicity'
race_studentcount_df = studentperformance_df['race_ethnicity'].value_counts()
race_studentcount_df
# Out:
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# write code to group dataframe by 'lunch'
grouped_studentlunch_df=studentperformance_df.groupby('lunch')
grouped_studentlunch_df.apply(display)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 3                      none          47             57             44
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 17                     none          18             32             28
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 996                    none          62             55             55
# 997               completed          59             71             65
# 999                    none          77             86             86
#
# [355 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 4                      none          76             78             75
# 5                      none          71             83             78
# ..                      ...         ...            ...            ...
# 987               completed          81             75             76
# 991               completed          65             82             78
# 994                    none          63             63             62
# 995               completed          88             99             95
# 998               completed          68             78             77
#
# [645 rows x 8 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# write code to count the type of 'lunch'
studentlunch_count_df = studentperformance_df['lunch'].value_counts()
studentlunch_count_df
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
# write code to group dataframe by 'test_preparation_course'
grouped_test_df=data_df.groupby('test_preparation_course')
grouped_test_df.apply(display)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 1                 completed          69             90             88
# 6                 completed          88             95             92
# 8                 completed          64             64             67
# 13                completed          78             72             70
# 18                completed          46             42             46
# ..                      ...         ...            ...            ...
# 990               completed          86             81             75
# 991               completed          65             82             78
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
#
# [358 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 996                    none          62             55             55
# 999                    none          77             86             86
#
# [642 rows x 8 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# write code to count the status of 'test_preparation_course'
test_studentcount_df = studentperformance_df['test_preparation_course'].value_counts()
test_studentcount_df
# Out:
# test_preparation_course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
# write code to group dataframe by 'parental_level_of_education'
grouped_parentallevel_df=studentperformance_df.groupby('parental_level_of_education')
grouped_parentallevel_df.apply(display)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 19   female        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 968  female        group E          associate's degree      standard
# 977    male        group C          associate's degree      standard
# 979  female        group C          associate's degree      standard
# 986  female        group C          associate's degree      standard
# 992  female        group D          associate's degree  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 3                      none          47             57             44
# 5                      none          71             83             78
# 10                     none          58             54             52
# 11                     none          40             52             43
# 19                     none          54             58             61
# ..                      ...         ...            ...            ...
# 968                    none          68             76             67
# 977                    none          62             65             58
# 979                    none          91             95             94
# 986                    none          40             59             51
# 992                    none          55             76             76
#
# [222 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 24                completed          74             71             80
# 27                     none          67             69             75
# 60                completed          79             74             72
# 77                completed          80             78             81
# ..                      ...         ...            ...            ...
# 916               completed         100            100            100
# 933               completed          70             75             74
# 969                    none          75             84             80
# 970                    none          89            100            100
# 993                    none          62             72             74
#
# [118 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 12   female        group B                 high school      standard
# 16     male        group C                 high school      standard
# 20     male        group D                 high school      standard
# ..      ...            ...                         ...           ...
# 985    male        group A                 high school      standard
# 990    male        group E                 high school  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 12                     none          65             81             73
# 16                     none          88             89             86
# 20                     none          66             69             63
# ..                      ...         ...            ...            ...
# 985                    none          57             51             54
# 990               completed          86             81             75
# 994                    none          63             63             62
# 996                    none          62             55             55
# 997               completed          59             71             65
#
# [196 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 79   female        group E             master's degree      standard
# 106  female        group D             master's degree      standard
# 128    male        group D             master's degree      standard
# 130    male        group D             master's degree      standard
# 162    male        group B             master's degree  free/reduced
# 164  female        group E             master's degree      standard
# 167  female        group B             master's degree  free/reduced
# 175  female        group C             master's degree      standard
# 178  female        group B             master's degree  free/reduced
# 180    male        group C             master's degree  free/reduced
# 194  female        group C             master's degree      standard
# 225  female        group E             master's degree  free/reduced
# 253    male        group D             master's degree      standard
# 259  female        group C             master's degree  free/reduced
# 316  female        group D             master's degree      standard
# 377  female        group D             master's degree  free/reduced
# 382    male        group C             master's degree  free/reduced
# 389    male        group D             master's degree      standard
# 410  female        group D             master's degree      standard
# 422  female        group D             master's degree  free/reduced
# 478  female        group D             master's degree      standard
# 500  female        group D             master's degree      standard
# 504  female        group D             master's degree  free/reduced
# 508    male        group C             master's degree      standard
# 514  female        group B             master's degree  free/reduced
# 523    male        group C             master's degree  free/reduced
# 544  female        group D             master's degree      standard
# 549    male        group C             master's degree      standard
# 557    male        group C             master's degree  free/reduced
# 567  female        group D             master's degree  free/reduced
# 579  female        group D             master's degree      standard
# 600  female        group D             master's degree      standard
# 604    male        group D             master's degree  free/reduced
# 607  female        group C             master's degree  free/reduced
# 618    male        group D             master's degree      standard
# 685  female        group E             master's degree      standard
# 713    male        group D             master's degree      standard
# 735    male        group C             master's degree      standard
# 752    male        group C             master's degree  free/reduced
# 781  female        group B             master's degree      standard
# 789  female        group C             master's degree  free/reduced
# 812  female        group C             master's degree      standard
# 845    male        group E             master's degree      standard
# 846    male        group C             master's degree      standard
# 850    male        group C             master's degree      standard
# 861  female        group E             master's degree  free/reduced
# 892  female        group A             master's degree  free/reduced
# 900    male        group D             master's degree      standard
# 901  female        group C             master's degree      standard
# 940    male        group C             master's degree  free/reduced
# 941  female        group D             master's degree      standard
# 957  female        group D             master's degree      standard
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 2                      none          90             95             93
# 14                     none          50             53             58
# 18                completed          46             42             46
# 25                     none          73             74             72
# 29                     none          62             70             75
# 32                     none          56             72             65
# 79                     none          62             68             68
# 106                    none          87            100            100
# 128                    none          82             82             74
# 130                    none          89             84             82
# 162                    none          49             53             52
# 164                    none          81             92             91
# 167               completed          58             76             78
# 175               completed          81             91             87
# 178               completed          52             70             62
# 180               completed          62             68             75
# 194               completed          69             84             85
# 225                    none          45             56             54
# 253                    none          80             80             72
# 259               completed          65             81             81
# 316               completed          77             82             91
# 377               completed          85             95            100
# 382                    none          79             81             71
# 389                    none          73             70             75
# 410               completed          70             71             74
# 422               completed          47             58             67
# 478                    none          55             64             70
# 500                    none          74             79             82
# 504                    none          40             59             54
# 508                    none          79             78             77
# 514               completed          77             97             94
# 523                    none          54             59             50
# 544                    none          64             63             66
# 549                    none          79             72             69
# 557                    none          61             67             66
# 567               completed          61             71             78
# 579                    none          53             61             68
# 600                    none          54             60             63
# 604               completed          84             89             90
# 607                    none          40             58             54
# 618                    none          95             81             84
# 685               completed          94             99            100
# 713                    none          81             81             84
# 735                    none          67             57             59
# 752               completed          79             77             75
# 781                    none          77             90             84
# 789                    none          52             65             61
# 812               completed          54             64             67
# 845                    none          90             85             84
# 846               completed          91             85             85
# 850                    none          71             67             67
# 861                    none          81             86             87
# 892                    none          50             67             73
# 900                    none          85             84             89
# 901                    none          73             78             74
# 940               completed          72             66             72
# 941                    none          78             91             96
# 957                    none          92            100            100
# 995               completed          88             99             95
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 13     male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 976    male        group B                some college  free/reduced
# 983  female        group A                some college      standard
# 989  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 1                 completed          69             90             88
# 4                      none          76             78             75
# 6                 completed          88             95             92
# 7                      none          40             43             39
# 13                completed          78             72             70
# ..                      ...         ...            ...            ...
# 976               completed          60             62             60
# 983               completed          78             87             91
# 989               completed          67             86             83
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [226 rows x 8 columns]
#      gender race_ethnicity parental_level_of_education         lunch  \
# 15   female        group C            some high school      standard
# 17   female        group B            some high school  free/reduced
# 23   female        group C            some high school      standard
# 37   female        group D            some high school  free/reduced
# 54   female        group C            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 982    male        group B            some high school      standard
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 988  female        group A            some high school  free/reduced
# 991  female        group B            some high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 15                     none          69             75             78
# 17                     none          18             32             28
# 23                     none          69             73             73
# 37                     none          50             64             59
# 54                completed          71             84             87
# ..                      ...         ...            ...            ...
# 982               completed          79             85             86
# 984                    none          74             75             82
# 987               completed          81             75             76
# 988                    none          44             45             45
# 991               completed          65             82             78
#
# [179 rows x 8 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# write code to count the different type of 'parental_level_of_education'
stuparental_count_df = studentperformance_df['parental_level_of_education'].value_counts()
stuparental_count_df
# Out:
# parental_level_of_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Visualize data and identify insights at each step.

# %% [markdown]
# ### 3a. Plot the distribution of gender using pie chart.

# %%
# write code to store grouped 'gender' count in a variable
studentgender_count_df = studentperformance_df['gender'].value_counts()
studentgender_labels = studentgender_count_df.index

# write code to store grouped 'gender' keys in a variable as pie chart label
# write code to plot the 'gender' distribution pie chart:

# 1. set background color of the outer area of the plot and figure size (6, 6)
plt.figure(figsize=(6, 6))
colors = ['#FF69B4', '#6495ED']
plt.rcParams['axes.facecolor'] = 'lightgray'

# 2. plot pie chart using 'gender' count and label
plt.pie(studentgender_count_df, labels=studentgender_labels, autopct='%1.1f%%', startangle=140, colors=colors)

# 3. add title of pie chart
plt.title('Gender Distribution')

# 4. show plot
plt.show()

# %% [markdown]
# ### 3b. Plot the distribution of ethnicity using bar chart.

# %%
# write code to store grouped 'race_ethnicity' count in a variable
race_count_df = studentperformance_df['race_ethnicity'].value_counts()
race_labels = race_count_df.index

# write code to store grouped 'race_ethnicity' keys in a variable as bar chart x-axis label
x_pos = np.arange(len(race_labels))

# create x-axis position for each group of 'race_ethnicity'

# write code to plot the 'race_ethnicity' distribution bar chart:
# 1. set background color of the outer area of the plot and figure size (10, 5)
plt.figure(figsize=(10, 5))
plt.rcParams['axes.facecolor'] = 'skyblue'

# 2. plot bar chart using 'race_ethnicity' and count
plt.bar(x_pos, race_count_df, color='hotpink')

# 3. add title of bar chart
plt.title('Race/Ethnicity Distribution')

# 4. add x-axis and y-axis label
plt.xlabel('Race/Ethnicity')
plt.ylabel('Count')

# 5. replace x-ticks with 'race_ethnicity' groups
plt.xticks(x_pos, race_labels)

# 6. show plot
plt.show()

# %% [markdown]
# ### 3c. Plot the distribution of lunch using pie chart.

# %%
# write code to store grouped 'lunch' count in a variable
lunch_count_df = studentperformance_df['lunch'].value_counts()


# write code to store grouped 'lunch' keys in a variable as pie chart label
lunch_labels = lunch_count_df.index

# write code to plot the 'lunch' distribution pie chart:

# 1. set background color of the outer area of the plot and figure size (6, 6)
plt.figure(figsize=(6, 6))
plt.rcParams['axes.facecolor'] = 'lightgray'

# 2. plot pie chart using lunch type count and label
plt.pie(lunch_count_df, labels=lunch_labels, autopct='%1.1f%%', startangle=140, colors=colors)

# 3. add title of pie chart
plt.title('Lunch Distribution')
# 4. show plot
plt.show()

# %% [markdown]
# ### 3d. Plot the distribution of test preparation course using bar chart.

# %%
# write code to store grouped 'test_preparation_course' count in a variable
test_count_df = studentperformance_df['test_preparation_course'].value_counts()

# write code to store grouped 'test_preparation_course' keys in a variable as bar chart x-axis label
test_labels = test_count_df.index

# create x-axis position for each group of 'test_preparation_course'
x_pos2= np.arange(len(test_labels))

# write code to plot the 'test_preparation_course' distribution bar chart:

# 1. set background color of the outer area of the plot and figure size (8, 4)
plt.figure(figsize=(8, 4))
plt.rcParams['axes.facecolor'] = 'skyblue'

# 2. plot bar chart using 'test_preparation_course' and count
plt.bar(x_pos2, test_count_df, color='lightpink')

# 3. add title of bar chart
plt.title('Test Preparation Course Distribution')

# 4. add x-axis and y-axis label
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')

# 5. replace x-ticks with 'test_preparation_course' groups
plt.xticks(x_pos2, test_labels)
# 6. show plot
plt.show()

# %% [markdown]
# ### 3e. Plot the distribution of parental level of education and math’s score and identify outlier.

# %%
# use seaborn package
import seaborn as sns

# set background color of the outer area of the plot (15, 8)
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# using seaborn boxplot, plot "parental_level_of_education" against "math_score"
sns.boxplot(x='parental_level_of_education', y='math_score', data=studentperformance_df)
plt.title('Parental Level of Education vs. Math Score')

plt.show()

# %% [markdown]
# ### 3f. Plot the relation between gender and each score using box plot.

# %%
# set background color of the outer area of the plot (6, 6)
plt.figure(figsize=(6, 6))
sns.set_style("whitegrid")
# using seaborn boxplot, plot "gender" against "math_score"
sns.boxplot(x='gender', y='math_score', data=studentperformance_df)
plt.title('Gender vs. Math Score')
plt.show()

# %%
# set background color of the outer area of the plot (6, 6)
plt.figure(figsize=(6, 6))
sns.set_style("whitegrid")

# using seaborn boxplot, plot "gender" against "reading_score"
sns.boxplot(x='gender', y='reading_score', data=data_df)
plt.title('Gender vs. Reading Score')
plt.show()

# %%
# set background color of the outer area of the plot (6, 6)
plt.figure(figsize=(6, 6))
sns.set_style("whitegrid")
# using seaborn boxplot, plot "gender" against "writing_score"
sns.boxplot(x='gender', y='writing_score', data=studentperformance_df)
plt.title('Gender vs. Writing Score')
plt.show()

# %% [markdown]
# ### 3g. Plot relation between reading score, writing score and maths score using scatter plot.

# %%
# write code to plot the 'reading_score' vs 'writing_score' scatter plot:
# 1. set background color of the outer area of the plot and figure size (6, 6)
plt.figure(figsize=(6, 6))
plt.rcParams['axes.facecolor'] = 'lightgray'

# 2. plot scatter plot using 'reading_score' against 'writing_score'
plt.scatter(studentperformance_df['reading_score'], studentperformance_df['writing_score'], alpha=0.5)

# 3. add title of scatter plot
plt.title('Reading Score vs Writing Score')

# 4. add x-axis and y-axis label
plt.xlabel('Reading Score')
plt.ylabel('Writing Score')

# 5. show plot
plt.show()

# %%
# write code to plot the 'reading_score' vs 'math_score' scatter plot:
# 1. set background color of the outer area of the plot and figure size (6, 6)
plt.figure(figsize=(6, 6))
plt.rcParams['axes.facecolor'] = 'lightgray'

# 2. plot scatter plot using 'reading_score' against 'math_score'
plt.scatter(studentperformance_df['reading_score'], studentperformance_df['math_score'], alpha=0.5)

# 3. add title of scatter plot
plt.title('Reading Score vs Math Score')

# 4. add x-axis and y-axis label
plt.xlabel('Reading Score')
plt.ylabel('Math Score')

# 5. show plot
plt.show()

# %%
# write code to plot the 'writing_score' vs 'math_score' scatter plot:
# 1. set background color of the outer area of the plot and figure size (6, 6)
plt.figure(figsize=(6, 6))
plt.rcParams['axes.facecolor'] = 'lightgray'

# 2. plot scatter plot using 'writing_score' against 'math_score'
plt.scatter(data_df['writing_score'], data_df['math_score'], alpha=0.5)

# 3. add title of scatter plot
plt.title('Writing Score vs Math Score')

# 4. add x-axis and y-axis label
plt.xlabel('Writing Score')
plt.ylabel('Math Score')
# 5. show plot
plt.show()

# %% [markdown]
# ## Submission:-
# #### 1. Save this file as "Index_Name_DE4002FP_Project.ipynb"
# #### 2. Submit file to myConnexion

# %%
20_fangxuan_DE4002FP_Project
